# %%
from pyspark.sql import SparkSession
from itertools import product

from main import main
from query1 import *
from query2 import *
from query3 import *
from query4 import *
from load import *

# %%
main()
# Out:
# Initializing spark session
# Loading crime data dataframe
# +--------------+------+
# |Vict Age Group| count|
# +--------------+------+
# |         25-64|115298|
# |         18-24| 32197|
# |           <18| 15321|
# |           >64|  5676|
# +--------------+------+
#
# Execution time for query1_dataframe: 1.5002 seconds
# +--------------+------+
# |Vict Age Group| count|
# +--------------+------+
# |         25-64|115298|
# |         18-24| 32197|
# |           <18| 15321|
# |           >64|  5676|
# +--------------+------+
#
# Execution time for query1_rdd: 13.5813 seconds
# Running query 2 RDD
# +----+-----------+--------------------+---+
# |year|   precinct|    closed_case_rate|  #|
# +----+-----------+--------------------+---+
# |2010|    Rampart| 0.32847134489491214|  1|
# |2010|    Olympic|  0.3151528982199909|  2|
# |2010|     Harbor|  0.2936028339237341|  3|
# |2010|West Valley| 0.25979070018340705|  4|
# |2010| Hollenbeck|  0.2520928976505536|  5|
# ...
